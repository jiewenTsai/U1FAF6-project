# %% [markdown]
# ## Chapter 3

# %% [markdown]
# $$\alpha + \beta \to \gamma$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x: x**2 + 3*x + 4

x = np.random.normal(size=100)
x.sort()

# %%
plt.plot(x, f(x))
